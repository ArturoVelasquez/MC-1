# %%
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.fftpack import ifft

# %%
monthrg = np.genfromtxt(os.path.expanduser("https://raw.githubusercontent.com/ComputoCienciasUniandes/MetodosComputacionalesDatos/master/hands_on/solar/monthrg.dat"),
                        skip_header=int((1900-1610)*12))

# %%
anio = monthrg[:,0]+((monthrg[:,1]-1)*(1/12))
promedio = monthrg[:,3]

# %%
plt.plot(anio,promedio)

# %%
#Transformada del promedio
DFTmanchas = np.fft.fft(promedio)
print(DFTmanchas)
#freqsManchas = fts(DFTmanchas)
absFreqsManchas = np.absolute(DFTmanchas)

#Transformada del tiempo
frecuencia = np.fft.fftfreq(anio.size,d=1/12)
# Out:
# [ 70822.00000000   +0.j          -4792.40806282+9383.28421042j
#    2135.11573300+4045.46771301j ...,  -3206.33205551-6344.251506j
#    2135.11573300-4045.46771301j  -4792.40806282-9383.28421042j]

# %%
plt.plot(frecuencia,absFreqsManchas,'ko')
DFTmanchas[np.abs(frecuencia)>=0.2]=0
plt.xlim(-0.4,0.4)
# Out:
# (-0.4, 0.4)

# %%
absFreqsManchas = np.absolute(DFTmanchas)
ynuevo=ifft(DFTmanchas)
plt.plot(anio,np.abs(ynuevo))

# %%
promedio.size
# Out:
# 1152

# %%
len(promedio)
# Out:
# 1152

# %%
frecuencia
# Out:
# array([ 0.        ,  0.01041667,  0.02083333, ..., -0.03125   ,
#        -0.02083333, -0.01041667])

# %%
1152/12
# Out:
# 96.0

# %%
print(absFreqsManchas)
# Out:
# [ 70822.          10536.28006529   4574.33363566 ...,   7108.45218185
#    4574.33363566  10536.28006529]

# %%
np.amin(absFreqsManchas)
# Out:
# 6.8927581518372651

# %%
print(promedio[anio>1995])
# Out:
# [ 39.6  35.4  11.   15.1  18.3  17.   18.5  12.5  13.9  11.7   7.6]
